# %% [markdown]
# <a href="https://colab.research.google.com/github/datasigntist/deeplearning/blob/master/Introduction_to_Genetic_Computing_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Challenge**
#
# Description
#
# The eight queens puzzle is the problem of placing eight chess queens on an 8×8 chessboard so that no two queens threaten each other; thus, a solution requires that no two queens share the same row, column, or diagonal. The eight queens puzzle is an example of the more general n queens problem of placing n non-attacking queens on an n×n chessboard. (Source : https://en.wikipedia.org/wiki/Eight_queens_puzzle )
#
# Challenge
#
# The challenge is to generate one right sequence through Genetic Programming. The sequence has to be 8 numbers between 0 to 7. Each number represents the positions the Queens can be placed. Each number refers to the row number in the specific column
#
# 0 3 4 5 6 1 2 4
#
# · 0 is the row number in the column 0 where the Queen can be placed
#
# · 3 is the row number in the column 1 where the Queen can be placed
#
#
# This challenge can have 92 correct sequences. Our challenege is to generate any of those correct sequence.

# %%
import _thread
import time
import random
import numpy as np
from numpy.random import choice
import pandas as pd
import threading 
import sys


global return_code,right_sequence
return_code="0"

def main():
    return_list1=[]
    global return_code
    global right_sequence
    global loop_no
    
    ##### Below variables can be tuned #####
    size_of_chess=8
    mutationRate = 0.01
    totalPopulation = 150
    crossOver = 0.5
    generationCount = 1000
    ########################################
    
    
    return_list1=NQueens(size_of_chess).solve() 

    for index in range(len(return_list1)):
            thread_name=''.join(return_list1[index])
            thread_instance = threading.Thread(target=preprocessing, args=(size_of_chess,thread_name,mutationRate,totalPopulation,crossOver,generationCount,)) 
            thread_instance.start()
    print_str="\n"+" ***** "+ right_sequence +" is the correct sequence which is generated first in generation no :"+loop_no +" ***** "
    print(print_str)
    
def inital_population(totalPopulation,size_of_chess,target,secure_random,alpha_list):     
      populationData1 = []
      fitnessData1 = []
      for outloop in range(totalPopulation):
            randomData = []
            fitnessScore = 0
            for inloop in range(size_of_chess):
                     selectedData = secure_random.choice(alpha_list)
                     if (selectedData == target[inloop]):
                           fitnessScore = fitnessScore + 1
                     randomData.append(selectedData)
            populationData1.append(randomData)
            fitnessData1.append(fitnessScore)
      return (populationData1,fitnessData1)
      


def preprocessing(size_of_chess,thread_name,mutationRate,totalPopulation,crossOver,generationCount): 
      global return_code,loop_no
      
     
      
      secure_random = random.SystemRandom()
      target = thread_name
      alpha_list = [chr(x) for x in range(ord('0'), ord('7')+1 )]
      populationData = []
      fitnessData = []
      populationData,fitnessData=inital_population(totalPopulation,size_of_chess,target,secure_random,alpha_list)
      probabilityDist = []
      for outloop in range(totalPopulation):
            probabilityDist.append(fitnessData[outloop]/len(target))
      probDataFrame = pd.DataFrame({'String':populationData,'FitnessScore':fitnessData,'Probability':probabilityDist})
      probDataFrame = probDataFrame.sort_values(['Probability'],ascending=False)
      probDataFrame = probDataFrame.reset_index(drop=True)
      probDataFrame.head()
      crossover_n_mutation(alpha_list,crossOver,target,generationCount,probDataFrame,thread_name,secure_random,populationData,probabilityDist,fitnessData)


        
        
def crossover_n_mutation(alpha_list,crossOver,target,generationCount,probDataFrame,thread_name,secure_random,populationData,probabilityDist,fitnessData):
      global return_code,right_sequence,loop_no

      crossOverPoint = int(crossOver*len(target))
      #print("\n")
      for loop in range(generationCount):
        if return_code=="1":
              sys.exit(0)
        else:
              draw=[]
              draw.append(probDataFrame[0:1]["String"].values[0])
              draw.append(probDataFrame[1:2]["String"].values[0])
              if (getFitnessScore(draw[0],target)==len(target) | getFitnessScore(draw[1],target)==len(target)):
                    print_str=""
                    print_str0=''.join([elem for elem in draw[0]])
                    print_str1=''.join([elem for elem in draw[1]])
                    #print_str="Final score|draw[0]:"+print_str0+"|FS:"+str(getFitnessScore(draw[0],target))+"|draw[1]:"+print_str1+"|FS:"+str(getFitnessScore(draw[1],target))
                    #print_str="Final score|draw[0]:"+print_str0+"|FS:"+getFitnessScore(draw[0],target)
                    print(print_str)
                    
                    return_code="1"
                    right_sequence=thread_name
                    
                    loop_no=str(loop)
                    #print(probDataFrame.head(30))
                    sys.exit(0)
                    break
              child1 = draw[0][0:crossOverPoint]+draw[1][crossOverPoint:]
              child2 = draw[1][0:crossOverPoint]+draw[0][crossOverPoint:]
              child1[random.randint(0,len(target)-1)] = secure_random.choice(alpha_list)
              child2[random.randint(0,len(target)-1)] = secure_random.choice(alpha_list)
              populationData.append(child1)
              populationData.append(child2)
              fitnessData = []
              totalPopulation = len(populationData)
              for outloop in range(totalPopulation):
                    fitnessScore = getFitnessScore(populationData[outloop],target)
                    fitnessData.append(fitnessScore)
              probabilityDist = []
              for outloop in range(totalPopulation):
                    probabilityDist.append(fitnessData[outloop]/sum(fitnessData))
              probDataFrame = pd.DataFrame({'String':populationData,'FitnessScore':fitnessData,'Probability':probabilityDist})
              probDataFrame = probDataFrame.sort_values(['Probability'],ascending=False)
              probDataFrame = probDataFrame.reset_index(drop=True)
              if return_code=="1":
                    sys.exit(0)
              else:
                    
                    a=""
                    #op_string="\n"+'Thread '+str(thread_name)+' Generation '+str(loop)+' '+' Average Fitness Score '+str(probDataFrame["FitnessScore"].mean())+' '+ ''.join(elem for elem in child1)+' '+str(getFitnessScore(child1,target))+' '+''.join(elem for elem in child2)+' '+str(getFitnessScore(child2,target))
                    op_string="\n"+'Thread '+str(thread_name)+' Generation '+str(loop)+' '+'|Child1 :'+ ''.join(elem for elem in child1)+'|FS of Child1: '+str(getFitnessScore(child1,target))+'|Child2 :'+''.join(elem for elem in child2)+'|FS of Child2 :'+str(getFitnessScore(child2,target))
                    print(op_string)
                    
            
        


    

def getFitnessScore(data,target):

          data = ''.join([elem for elem in data])
          fitnessScore = 0
          for inloop in range(len(target)):
                if (data[inloop] == target[inloop]):
                        fitnessScore = fitnessScore + 1
          #print ("data :",data)
          #print ("target :", target)
          #print ("fitness score :", fitnessScore)
          return fitnessScore


    

def maxProb(probabilityDist):
        probabilityList = [f for f in set(probabilityDist)]
        return (probabilityList[len(probabilityList)-2])


def viewElement(data):
          data = ''.join([elem for elem in data])
          return data

        
        
class NQueens:
    """Generate all valid solutions for the n queens puzzle"""
    def __init__(self,size):
        # Store the puzzle (problem) size and the number of valid solutions
        self.size = size
        self.solutions = 0


    def solve(self):
        """Solve the n queens puzzle and print the number of solutions"""

        final_list=[]
        positions = [-1] * self.size
        self.put_queen(positions, 0,final_list)
        #print("Found", self.solutions, "solutions.")
        return final_list


    def put_queen(self, positions, target_row,final_list):
        """
        Try to place a queen on target_row by checking all N possible cases.
        If a valid place is found the function calls itself trying to place a queen
        on the next row until all N queens are placed on the NxN board.
        """
        # Base (stop) case - all N rows are occupied
        
        if target_row == self.size:
            
            self.show_full_board(positions,final_list)
            # self.show_short_board(positions)
            self.solutions += 1
        else:
            # For all N columns positions try to place a queen
            for column in range(self.size):
                # Reject all invalid positions
                if self.check_place(positions, target_row, column):
                    positions[target_row] = column
                    self.put_queen(positions, target_row + 1,final_list)
        


    def check_place(self, positions, ocuppied_rows, column):
        """
        Check if a given position is under attack from any of
        the previously placed queens (check column and diagonal positions)
        """
        for i in range(ocuppied_rows):
            if positions[i] == column or \
                positions[i] - i == column - ocuppied_rows or \
                positions[i] + i == column + ocuppied_rows:

                return False
        return True

    def show_full_board(self, positions,final_list):
        """Show the full NxN board"""
        
        small_list=[]
        for row in range(self.size):
            line = ""
            for column in range(self.size):
                if positions[row] == column:
                    #line += "Q "
                    small_list.append(str(column))
                    #print("Pervez :{},{}".format(row,column))
                #else:
                    #line += ". "
                    
            #print(line)
        final_list.append(small_list)
        #print("\n")
        

    def show_short_board(self, positions):
        """
        Show the queens positions on the board in compressed form,
        each number represent the occupied column position in the corresponding row.
        """
        line = ""
        for i in range(self.size):
            line += str(positions[i]) + " "
        #print(line)

if __name__ == "__main__":
    # execute only if run as a script

    main()
# Out:
# Thread 05726314 Generation 0 |Child1 :60726514|FS of Child1: 5|Child2 :02756464|FS of Child2 :4
#
# Thread 05726314 Generation 1 |Child1 :60726763|FS of Child1: 3|Child2 :00727514|FS of Child2 :5
#
# Thread 04752613 Generation 0 |Child1 :45056647|FS of Child1: 2|Child2 :04742605|FS of Child2 :5
# Thread 05726314 Generation 2 |Child1 :04726514|FS of Child1: 6|Child2 :02727514|FS of Child2 :5
#
#
# Thread 05726314 Generation 3 |Child1 :04727514|FS of Child1: 5|Child2 :02726414|FS of Child2 :6
#
# Thread 06357142 Generation 0 |Child1 :30370046|FS of Child1: 2|Child2 :01257260|FS of Child2 :3
#
# Thread 06471352 Generation 0 |Child1 :36431357|FS of Child1: 5|Child2 :04616454|FS of Child2 :2
#
# Thread 06357142 Generation 1 |Child1 :00347260|FS of Child1: 3|Child2 :11257262|FS of Child2 :3
# Thread 04752613 Generation 1 |Child1 :04742602|FS of Child1: 5|Child2 :45756605|FS of Child2 :3
#
#
# Thread 14630752 Generation 0 |Child1 :21130471|FS of Child1: 2|Child2 :54432652|FS of Child2 :4
#
# Thread 13572064 Generation 0 |Child1 :00572363|FS of Child1: 4|Child2 :22545364|FS of Child2 :3
#
# Thread 15063724 Generation 0 |Child1 :15163001|FS of Child1: 4|Child2 :15046727|FS of Child2 :5
#
# Thread 06471352 Generation 1 |Child1 :36417152|FS of Child1: 4|Child2 :40454357|FS of Child2 :3
#
# Thread 04752613 Generation 2 |Child1 :45752652|FS of Child1: 4|Child2 :04742603|FS of Child2 :6
# Thread 06471352 Generation 2 |Child1 :36437152|FS of Child1: 4|Child2 :37411357|FS of Child2 :4
#
# Thread 16257403 Generation 0 |Child1 :12217413|FS of Child1: 5|Child2 :53650443|FS of Child2 :3
#
# Thread 06471352 Generation 3 |Child1 :36431757|FS of Child1: 4|Child2 :37411657|FS of Child2 :3
#
# Thread 06357142 Generation 2 |Child1 :03377360|FS of Child1: 3|Child2 :03157762|FS of Child2 :4
#
# Thread 14630752 Generation 1 |Child1 :50432652|FS of Child1: 3|Child2 :11135652|FS of Child2 :4
# Thread 05726314 Generation 4 |Child1 :02726534|FS of Child1: 5|Child2 :04726414|FS of Child2 :6
#
#
#
# Thread 15720364 Generation 0 |Child1 :15647601|FS of Child1: 2|Child2 :14760761|FS of Child2 :4
#
# Thread 13572064 Generation 1 |Child1 :50575364|FS of Child1: 4|Child2 :30571363|FS of Child2 :3
#
# Thread 14602753 Generation 0 |Child1 :44372202|FS of Child1: 2|Child2 :54702766|FS of Child2 :4
#
# Thread 15063724 Generation 1 |Child1 :15046723|FS of Child1: 5|Child2 :15066727|FS of Child2 :6
#
# Thread 06471352 Generation 4 |Child1 :36434757|FS of Child1: 3|Child2 :36431357|FS of Child2 :5
#
# Thread 16470352 Generation 0 |Child1 :15324413|FS of Child1: 1|Child2 :76400312|FS of Child2 :5
#
# Thread 05726314 Generation 5 |Child1 :74726514|FS of Child1: 5|Child2 :04626414|FS of Child2 :5
#
# Thread 06357142 Generation 3 |Child1 :03157263|FS of Child1: 3|Child2 :00377712|FS of Child2 :4
#
# Thread 05726314 Generation 6 |Child1 :02726614|FS of Child1: 6|Child2 :04746414|FS of Child2 :5
# Thread 13572064 Generation 2 |Child1 :70572363|FS of Child1: 4|Child2 :00575364|FS of Child2 :4
#
#
# Thread 04752613 Generation 3 |Child1 :04742502|FS of Child1: 4|Child2 :04742203|FS of Child2 :5
#
# Thread 13572064 Generation 3 |Child1 :00575362|FS of Child1: 3|Child2 :30575364|FS of Child2 :4
#
# Thread 14630752 Generation 2 |Child1 :11132652|FS of Child1: 4|Child2 :14135652|FS of Child2 :5
#
# Thread 16257403 Generation 1 |Child1 :12310403|FS of Child1: 4|Child2 :32217410|FS of Child2 :3
# Thread 17502463 Generation 0 |Child1 :74522752|FS of Child1: 2|Child2 :27537465|FS of Child2 :4
#
# Thread 15063724 Generation 2 |Child1 :15066753|FS of Child1: 5|Child2 :15066727|FS of Child2 :6
#
#
# Thread 06471352 Generation 5 |Child1 :36461357|FS of Child1: 5|Child2 :36421357|FS of Child2 :5
#
# Thread 04752613 Generation 4 |Child1 :04042203|FS of Child1: 4|Child2 :04742603|FS of Child2 :6
#
# Thread 14630752 Generation 3 |Child1 :14132653|FS of Child1: 4|Child2 :11135612|FS of Child2 :3
#
# Thread 15720364 Generation 1 |Child1 :74760761|FS of Child1: 3|Child2 :15340761|FS of Child2 :4
#
# Thread 20647135 Generation 0 |Child1 :70337635|FS of Child1: 4|Child2 :00531331|FS of Child2 :2
#
# Thread 06357142 Generation 4 |Child1 :00376762|FS of Child1: 3|Child2 :03117712|FS of Child2 :3
#
# Thread 17502463 Generation 1 |Child1 :27541465|FS of Child1: 4|Child2 :74507465|FS of Child2 :4
#
# Thread 15720364 Generation 2 |Child1 :15345761|FS of Child1: 3|Child2 :14710761|FS of Child2 :4
#
# Thread 05726314 Generation 7 |Child1 :02727414|FS of Child1: 5|Child2 :04720614|FS of Child2 :5
# Thread 04752613 Generation 5 |Child1 :04742303|FS of Child1: 5|Child2 :74742603|FS of Child2 :5
#
#
# Thread 15063724 Generation 3 |Child1 :15066726|FS of Child1: 6|Child2 :15060727|FS of Child2 :6
#
# Thread 06471352 Generation 6 |Child1 :36425357|FS of Child1: 4|Child2 :30431357|FS of Child2 :4
#
# Thread 06357142 Generation 5 |Child1 :00377062|FS of Child1: 4|Child2 :00377712|FS of Child2 :4
#
# Thread 14630752 Generation 4 |Child1 :64132652|FS of Child1: 4|Child2 :54435652|FS of Child2 :4
# Thread 17502463 Generation 2 |Child1 :77501465|FS of Child1: 5|Child2 :27545465|FS of Child2 :4
#
# Thread 05726314 Generation 8 |Child1 :32726514|FS of Child1: 5|Child2 :04726414|FS of Child2 :6
# Thread 20647135 Generation 1 |Child1 :70237305|FS of Child1: 3|Child2 :52547637|FS of Child2 :3
# Thread 14602753 Generation 1 |Child1 :54701766|FS of Child1: 3|Child2 :45672766|FS of Child2 :3
# Thread 13572064 Generation 4 |Child1 :30572363|FS of Child1: 4|Child2 :00535364|FS of Child2 :3
#
# Thread 15720364 Generation 3 |Child1 :14712761|FS of Child1: 3|Child2 :14760765|FS of Child2 :4
#
# Thread 20647135 Generation 2 |Child1 :70337632|FS of Child1: 3|Child2 :52547035|FS of Child2 :4
#
# Thread 20647135 Generation 3 |Child1 :52527635|FS of Child1: 3|Child2 :70307035|FS of Child2 :4
#
#
#
#
# Thread 20647135 Generation 4 |Child1 :70300635|FS of Child1: 3|Child2 :70337037|FS of Child2 :3
#
# Thread 16470352 Generation 1 |Child1 :76430312|FS of Child1: 5|Child2 :15321312|FS of Child2 :3
# Thread 24730615 Generation 0 |Child1 :36736036|FS of Child1: 2|Child2 :26666075|FS of Child2 :2
#
# Thread 15063724 Generation 4 |Child1 :15766726|FS of Child1: 5|Child2 :13060727|FS of Child2 :5
#
# Thread 17502463 Generation 3 |Child1 :77505475|FS of Child1: 4|Child2 :57541465|FS of Child2 :4
#
# Thread 13572064 Generation 5 |Child1 :30572313|FS of Child1: 3|Child2 :30575364|FS of Child2 :4
#
# Thread 24175360 Generation 0 |Child1 :15005106|FS of Child1: 1|Child2 :04105300|FS of Child2 :5
# Thread 16257403 Generation 2 |Child1 :12010403|FS of Child1: 4|Child2 :13317413|FS of Child2 :4
#
#
#
#
# Thread 04752613 Generation 6 |Child1 :04142603|FS of Child1: 5|Child2 :34742603|FS of Child2 :5
# Thread 20647135 Generation 5 |Child1 :70737035|FS of Child1: 4|Child2 :70207635|FS of Child2 :4
# Thread 14630752 Generation 5 |Child1 :14135656|FS of Child1: 4|Child2 :54435552|FS of Child2 :4
#
# Thread 06357142 Generation 6 |Child1 :00377067|FS of Child1: 3|Child2 :00277712|FS of Child2 :3
# Thread 24603175 Generation 0 |Child1 :37621176|FS of Child1: 3|Child2 :24343455|FS of Child2 :4
#
#
# Thread 06471352 Generation 7 |Child1 :36431257|FS of Child1: 4|Child2 :31461357|FS of Child2 :4
# Thread 24175360 Generation 1 |Child1 :04102330|FS of Child1: 4|Child2 :14005300|FS of Child2 :4
#
# Thread 20647135 Generation 6 |Child1 :70307035|FS of Child1: 4|Child2 :70737635|FS of Child2 :4
#
# Thread 14602753 Generation 2 |Child1 :54722766|FS of Child1: 3|Child2 :44672366|FS of Child2 :3
#
#
#
# Thread 16257403 Generation 3 |Child1 :12217423|FS of Child1: 5|Child2 :10317413|FS of Child2 :4
# Thread 24170635 Generation 0 |Child1 :25654635|FS of Child1: 4|Child2 :03170671|FS of Child2 :4
# Thread 24603175 Generation 1 |Child1 :24343055|FS of Child1: 4|Child2 :26423435|FS of Child2 :3
# Thread 24730615 Generation 1 |Child1 :36733136|FS of Child1: 2|Child2 :74236075|FS of Child2 :3
# Thread 05726314 Generation 9 |Child1 :04746614|FS of Child1: 5|Child2 :02726413|FS of Child2 :5
# Thread 14630752 Generation 6 |Child1 :14133552|FS of Child1: 5|Child2 :54435612|FS of Child2 :3
#
#
# Thread 06471352 Generation 8 |Child1 :36461457|FS of Child1: 4|Child2 :36131357|FS of Child2 :4
# Thread 20647135 Generation 7 |Child1 :70737035|FS of Child1: 4|Child2 :70307235|FS of Child2 :4
#
# Thread 16470352 Generation 2 |Child1 :73430312|FS of Child1: 4|Child2 :76403312|FS of Child2 :4
#
# Thread 13572064 Generation 6 |Child1 :30575363|FS of Child1: 3|Child2 :10575364|FS of Child2 :5
#
# Thread 17502463 Generation 4 |Child1 :72501465|FS of Child1: 4|Child2 :57541465|FS of Child2 :4
#
#
#
#
# Thread 15720364 Generation 4 |Child1 :14760761|FS of Child1: 4|Child2 :14710165|FS of Child2 :4
#
# Thread 14630752 Generation 7 |Child1 :17135652|FS of Child1: 4|Child2 :14133552|FS of Child2 :5
#
# Thread 25147063 Generation 0 |Child1 :21147517|FS of Child1: 4|Child2 :05170217|FS of Child2 :2
# Thread 06357142 Generation 7 |Child1 :00377062|FS of Child1: 4|Child2 :40377712|FS of Child2 :3
#
# Thread 24175360 Generation 2 |Child1 :07105300|FS of Child1: 4|Child2 :14005400|FS of Child2 :3
#
#
#
#
# Thread 16257403 Generation 4 |Child1 :12213413|FS of Child1: 4|Child2 :12216423|FS of Child2 :4
# Thread 25164073 Generation 0 |Child1 :34164022|FS of Child1: 4|Child2 :03330373|FS of Child2 :2
# Thread 20647135 Generation 8 |Child1 :70307025|FS of Child1: 3|Child2 :70737205|FS of Child2 :3
# Thread 04752613 Generation 7 |Child1 :04712603|FS of Child1: 6|Child2 :06742603|FS of Child2 :5
# Thread 06471352 Generation 9 |Child1 :32431357|FS of Child1: 4|Child2 :36463357|FS of Child2 :4
#
#
# Thread 24175360 Generation 3 |Child1 :04105335|FS of Child1: 4|Child2 :14205300|FS of Child2 :4
#
# Thread 13572064 Generation 7 |Child1 :10072363|FS of Child1: 4|Child2 :30575364|FS of Child2 :4
#
# Thread 25164073 Generation 1 |Child1 :34160373|FS of Child1: 4|Child2 :34164062|FS of Child2 :4
#
# Thread 15063724 Generation 5 |Child1 :15060027|FS of Child1: 5|Child2 :15066777|FS of Child2 :5
#
#
# Thread 14630752 Generation 8 |Child1 :14133552|FS of Child1: 5|Child2 :11133552|FS of Child2 :4
# Thread 04752613 Generation 8 |Child1 :04772603|FS of Child1: 6|Child2 :04762603|FS of Child2 :6
#
# Thread 17502463 Generation 5 |Child1 :71501465|FS of Child1: 4|Child2 :57541405|FS of Child2 :3
# Thread 24603175 Generation 2 |Child1 :44473055|FS of Child1: 3|Child2 :24343576|FS of Child2 :4
# Thread 15720364 Generation 5 |Child1 :74710761|FS of Child1: 3|Child2 :14740165|FS of Child2 :4
#
# Thread 14602753 Generation 3 |Child1 :44172766|FS of Child1: 3|Child2 :54702766|FS of Child2 :4
#
#
# Thread 24730615 Generation 2 |Child1 :34235635|FS of Child1: 4|Child2 :77016075|FS of Child2 :1
#
# Thread 20647135 Generation 9 |Child1 :70203035|FS of Child1: 3|Child2 :71307635|FS of Child2 :3
# Thread 25147063 Generation 1 |Child1 :26145517|FS of Child1: 3|Child2 :41140267|FS of Child2 :3
#
# Thread 24170635 Generation 1 |Child1 :03174135|FS of Child1: 4|Child2 :03270670|FS of Child2 :3
#
#
# Thread 16470352 Generation 3 |Child1 :76431312|FS of Child1: 4|Child2 :76400317|FS of Child2 :4
# Thread 25160374 Generation 0 |Child1 :56161412|FS of Child1: 2|Child2 :22273372|FS of Child2 :3
#
# Thread 15063724 Generation 6 |Child1 :45066727|FS of Child1: 5|Child2 :15066326|FS of Child2 :5
#
#
# Thread 24175360 Generation 4 |Child1 :04102300|FS of Child1: 4|Child2 :14205300|FS of Child2 :4
#
#
# Thread 16257403 Generation 5 |Child1 :12217410|FS of Child1: 4|Child2 :42217423|FS of Child2 :4
#
# Thread 25164073 Generation 2 |Child1 :34167373|FS of Child1: 4|Child2 :34134062|FS of Child2 :3
# Thread 13572064 Generation 8 |Child1 :10572364|FS of Child1: 6|Child2 :30575364|FS of Child2 :4
# Thread 24603175 Generation 3 |Child1 :24343156|FS of Child1: 4|Child2 :26423572|FS of Child2 :3
# Thread 04752613 Generation 9 |Child1 :04762633|FS of Child1: 6|Child2 :04772604|FS of Child2 :5
#
#
# Thread 24170635 Generation 2 |Child1 :21654135|FS of Child1: 3|Child2 :03470671|FS of Child2 :3
# Thread 06471352 Generation 10 |Child1 :16431357|FS of Child1: 5|Child2 :36441357|FS of Child2 :5
#
# Thread 14630752 Generation 9 |Child1 :14173552|FS of Child1: 4|Child2 :14133752|FS of Child2 :6
#
# Thread 25307461 Generation 0 |Child1 :26307472|FS of Child1: 5|Child2 :35311131|FS of Child2 :3
# Thread 25160374 Generation 1 |Child1 :56164672|FS of Child1: 3|Child2 :26263372|FS of Child2 :4
# Thread 20647135 Generation 10 |Child1 :52540235|FS of Child1: 3|Child2 :70307055|FS of Child2 :3
# Thread 16470352 Generation 4 |Child1 :76420312|FS of Child1: 5|Child2 :76400316|FS of Child2 :4
#
#
#
#
#
#
#
# Thread 25164073 Generation 3 |Child1 :34167376|FS of Child1: 3|Child2 :34160373|FS of Child2 :4
#
# Thread 25160374 Generation 2 |Child1 :26263370|FS of Child1: 4|Child2 :56163375|FS of Child2 :4
# Thread 17502463 Generation 6 |Child1 :77541465|FS of Child1: 4|Child2 :71503465|FS of Child2 :4
#
#
#
# Thread 15063724 Generation 7 |Child1 :15066707|FS of Child1: 5|Child2 :15066627|FS of Child2 :5
#
# Thread 24730615 Generation 3 |Child1 :34236175|FS of Child1: 3|Child2 :34235635|FS of Child2 :4
#
# Thread 24175360 Generation 5 |Child1 :04175300|FS of Child1: 6|Child2 :14215300|FS of Child2 :4
#
# Thread 16257403 Generation 6 |Child1 :12212413|FS of Child1: 4|Child2 :12217123|FS of Child2 :4
#
# Thread 24170635 Generation 3 |Child1 :24652510|FS of Child1: 2|Child2 :24150674|FS of Child2 :5
#
# Thread 17502463 Generation 7 |Child1 :77505476|FS of Child1: 4|Child2 :77501461|FS of Child2 :5
# Thread 05726314 Generation 10 |Child1 :04726411|FS of Child1: 5|Child2 :01726414|FS of Child2 :6
#
#
#
#
# Thread 24603175 Generation 4 |Child1 :34623126|FS of Child1: 4|Child2 :24343455|FS of Child2 :4
# Thread 15720364 Generation 6 |Child1 :14740761|FS of Child1: 4|Child2 :14710165|FS of Child2 :4
#
# Thread 24175360 Generation 6 |Child1 :04174300|FS of Child1: 5|Child2 :64105300|FS of Child2 :5
#
# Thread 20647135 Generation 11 |Child1 :52547035|FS of Child1: 4|Child2 :30307035|FS of Child2 :4
#
# Thread 14630752 Generation 10 |Child1 :14133552|FS of Child1: 5|Child2 :74133752|FS of Child2 :5
#
# Thread 25160374 Generation 3 |Child1 :56163370|FS of Child1: 4|Child2 :20263375|FS of Child2 :4
#
# Thread 24730615 Generation 4 |Child1 :34235637|FS of Child1: 3|Child2 :36235635|FS of Child2 :3
#
#
# Thread 24170635 Generation 4 |Child1 :24154615|FS of Child1: 5|Child2 :03270174|FS of Child2 :2
# Thread 25703641 Generation 0 |Child1 :17703640|FS of Child1: 5|Child2 :76303251|FS of Child2 :3
# Thread 25147063 Generation 2 |Child1 :26247517|FS of Child1: 3|Child2 :21145267|FS of Child2 :4
#
# Thread 04752613 Generation 10 |Child1 :34742633|FS of Child1: 5|Child2 :04767603|FS of Child2 :5
#
#
# Thread 15720364 Generation 7 |Child1 :14710661|FS of Child1: 4|Child2 :15640162|FS of Child2 :4
#
# Thread 14602753 Generation 4 |Child1 :54202766|FS of Child1: 4|Child2 :54704766|FS of Child2 :3
#
# Thread 20647135 Generation 12 |Child1 :30507035|FS of Child1: 4|Child2 :52547036|FS of Child2 :3
#
#
# Thread 25307461 Generation 1 |Child1 :26301161|FS of Child1: 5|Child2 :26307473|FS of Child2 :5
#
#
# Thread 06357142 Generation 8 |Child1 :00377012|FS of Child1: 4|Child2 :00377066|FS of Child2 :3
#
# Thread 25703641 Generation 1 |Child1 :17702751|FS of Child1: 3|Child2 :15703640|FS of Child2 :6
# Thread 24730615 Generation 5 |Child1 :35235635|FS of Child1: 3|Child2 :30235635|FS of Child2 :3
#
# Thread 06471352 Generation 11 |Child1 :32441357|FS of Child1: 4|Child2 :36631357|FS of Child2 :4
# Thread 24175360 Generation 7 |Child1 :03175300|FS of Child1: 5|Child2 :64105200|FS of Child2 :4
# Thread 15720364 Generation 8 |Child1 :15640761|FS of Child1: 4|Child2 :64760162|FS of Child2 :3
# Thread 17502463 Generation 8 |Child1 :77531465|FS of Child1: 4|Child2 :77101461|FS of Child2 :4
#
# Thread 15063724 Generation 8 |Child1 :15066727|FS of Child1: 6|Child2 :15066737|FS of Child2 :5
# Thread 25160374 Generation 4 |Child1 :20266370|FS of Child1: 4|Child2 :56163375|FS of Child2 :4
#
#
#
# Thread 25704613 Generation 0 |Child1 :63767645|FS of Child1: 2|Child2 :20744623|FS of Child2 :5
#
# Thread 06357142 Generation 9 |Child1 :00347012|FS of Child1: 4|Child2 :00677062|FS of Child2 :3
#
# Thread 04752613 Generation 11 |Child1 :01742633|FS of Child1: 5|Child2 :04262603|FS of Child2 :5
#
# Thread 06357142 Generation 10 |Child1 :20377012|FS of Child1: 3|Child2 :00347662|FS of Child2 :4
#
#
#
#
# Thread 27360514 Generation 0 |Child1 :27014201|FS of Child1: 2|Child2 :26666530|FS of Child2 :3
#
# Thread 25713064 Generation 0 |Child1 :01732064|FS of Child1: 4|Child2 :62453034|FS of Child2 :3
#
# Thread 16257403 Generation 7 |Child1 :12214423|FS of Child1: 4|Child2 :17217413|FS of Child2 :5
#
# Thread 27360514 Generation 1 |Child1 :07316530|FS of Child1: 3|Child2 :26666536|FS of Child2 :3
#
# Thread 25147063 Generation 3 |Child1 :21140260|FS of Child1: 4|Child2 :26145261|FS of Child2 :4
#
# Thread 13572064 Generation 9 |Child1 :15575364|FS of Child1: 5|Child2 :10572334|FS of Child2 :5
#
# Thread 26174035 Generation 0 |Child1 :56370426|FS of Child1: 2|Child2 :05174757|FS of Child2 :3
#
# Thread 25317460 Generation 0 |Child1 :61527467|FS of Child1: 3|Child2 :65647477|FS of Child2 :3
#
# Thread 20647135 Generation 13 |Child1 :70407035|FS of Child1: 4|Child2 :35507035|FS of Child2 :3
#
# Thread 24170635 Generation 5 |Child1 :24454615|FS of Child1: 4|Child2 :24150654|FS of Child2 :5
#
# Thread 16470352 Generation 5 |Child1 :76420362|FS of Child1: 5|Child2 :46430312|FS of Child2 :5
#
# Thread 06471352 Generation 12 |Child1 :36731357|FS of Child1: 4|Child2 :36421357|FS of Child2 :5
#
# Thread 14602753 Generation 5 |Child1 :54202566|FS of Child1: 3|Child2 :54502766|FS of Child2 :4
#
# Thread 25160374 Generation 5 |Child1 :56156370|FS of Child1: 3|Child2 :30263375|FS of Child2 :3
#
# Thread 25307461 Generation 2 |Child1 :26301160|FS of Child1: 4|Child2 :26307473|FS of Child2 :5
#
# Thread 25317460 Generation 1 |Child1 :64327467|FS of Child1: 4|Child2 :65647457|FS of Child2 :3
#
# Thread 16257403 Generation 8 |Child1 :67217413|FS of Child1: 4|Child2 :12217410|FS of Child2 :4
#
# Thread 04752613 Generation 12 |Child1 :14742603|FS of Child1: 5|Child2 :02772603|FS of Child2 :5
#
# Thread 25703641 Generation 2 |Child1 :15703640|FS of Child1: 6|Child2 :17703642|FS of Child2 :5
#
# Thread 25713064 Generation 1 |Child1 :01712044|FS of Child1: 4|Child2 :41733034|FS of Child2 :4
#
# Thread 06471352 Generation 13 |Child1 :36461357|FS of Child1: 5|Child2 :36341357|FS of Child2 :4
#
# Thread 20647135 Generation 14 |Child1 :70307215|FS of Child1: 3|Child2 :70307025|FS of Child2 :3
#
# Thread 26175304 Generation 0 |Child1 :46115354|FS of Child1: 5|Child2 :36067324|FS of Child2 :3
#
# Thread 25713064 Generation 2 |Child1 :01753034|FS of Child1: 4|Child2 :41733014|FS of Child2 :4
# Thread 25164073 Generation 4 |Child1 :34167073|FS of Child1: 5|Child2 :34160373|FS of Child2 :4
#
# Thread 15720364 Generation 9 |Child1 :14160165|FS of Child1: 3|Child2 :54710761|FS of Child2 :3
#
# Thread 15063724 Generation 9 |Child1 :15066717|FS of Child1: 5|Child2 :15066427|FS of Child2 :5
#
# Thread 24603175 Generation 5 |Child1 :24346055|FS of Child1: 3|Child2 :21343455|FS of Child2 :3
#
# Thread 26174035 Generation 1 |Child1 :16374757|FS of Child1: 3|Child2 :05174737|FS of Child2 :4
#
# Thread 05726314 Generation 11 |Child1 :01726514|FS of Child1: 6|Child2 :04766414|FS of Child2 :5
#
# Thread 04752613 Generation 13 |Child1 :04762603|FS of Child1: 6|Child2 :04752603|FS of Child2 :7
#
# Thread 30471625 Generation 0 |Child1 :32401327|FS of Child1: 4|Child2 :70412224|FS of Child2 :3
#
# Thread 24730615 Generation 6 |Child1 :44235635|FS of Child1: 4|Child2 :34235665|FS of Child2 :4
#
#
# Thread 25317460 Generation 2 |Child1 :64327462|FS of Child1: 4|Child2 :65647467|FS of Child2 :4
#
# Thread 04752613 Generation 14 |Child1 :04722603|FS of Child1: 6|Child2 :05762603|FS of Child2 :5
#
# Thread 06357142 Generation 11 |Child1 :05347012|FS of Child1: 4|Child2 :04377662|FS of Child2 :4
#
# Thread 05726314 Generation 12 |Child1 :02726511|FS of Child1: 5|Child2 :01726412|FS of Child2 :5
#
# Thread 24175360 Generation 8 |Child1 :04175301|FS of Child1: 5|Child2 :04135300|FS of Child2 :5
#
# Thread 24170635 Generation 6 |Child1 :24154605|FS of Child1: 5|Child2 :24170654|FS of Child2 :6
#
# Thread 25307461 Generation 3 |Child1 :26307473|FS of Child1: 5|Child2 :46307473|FS of Child2 :4
#
# Thread 13572064 Generation 10 |Child1 :10572344|FS of Child1: 5|Child2 :20572364|FS of Child2 :5
#
# Thread 25164073 Generation 5 |Child1 :34140373|FS of Child1: 3|Child2 :34167073|FS of Child2 :5
#
# Thread 15720364 Generation 10 |Child1 :14710166|FS of Child1: 4|Child2 :64740761|FS of Child2 :3
# Thread 14602753 Generation 6 |Child1 :54302766|FS of Child1: 4|Child2 :54722766|FS of Child2 :3
#
#
# Thread 25160374 Generation 6 |Child1 :26263572|FS of Child1: 3|Child2 :46163370|FS of Child2 :4
# Thread 27360514 Generation 2 |Child1 :27416536|FS of Child1: 3|Child2 :26666530|FS of Child2 :3
#
# Thread 16470352 Generation 6 |Child1 :46430362|FS of Child1: 5|Child2 :76420312|FS of Child2 :5
#
# Thread 26175304 Generation 1 |Child1 :46117334|FS of Child1: 4|Child2 :36115354|FS of Child2 :5
#
# Thread 04752613 Generation 15 |Child1 :34752603|FS of Child1: 6|Child2 :04712601|FS of Child2 :5
#
# Thread 06471352 Generation 14 |Child1 :06431357|FS of Child1: 6|Child2 :36461357|FS of Child2 :5
#
# Thread 25307461 Generation 4 |Child1 :26307472|FS of Child1: 5|Child2 :26304473|FS of Child2 :4
#
# Thread 16470352 Generation 7 |Child1 :76423312|FS of Child1: 4|Child2 :76400311|FS of Child2 :4
# Thread 16257403 Generation 9 |Child1 :12017413|FS of Child1: 4|Child2 :17217313|FS of Child2 :4
# Thread 14630752 Generation 11 |Child1 :14123752|FS of Child1: 5|Child2 :74143752|FS of Child2 :4
#
#
#
# Thread 26175304 Generation 2 |Child1 :36117304|FS of Child1: 5|Child2 :26115254|FS of Child2 :5
#
# Thread 24603175 Generation 6 |Child1 :24340155|FS of Child1: 4|Child2 :26423255|FS of Child2 :3
#
# Thread 25160374 Generation 7 |Child1 :46163175|FS of Child1: 3|Child2 :20263360|FS of Child2 :3
# Thread 04752613 Generation 16 |Child1 :04752003|FS of Child1: 6|Child2 :04762603|FS of Child2 :6
#
#
# Thread 25704613 Generation 1 |Child1 :20344613|FS of Child1: 5|Child2 :43234663|FS of Child2 :3
#
# Thread 24730615 Generation 7 |Child1 :34235235|FS of Child1: 3|Child2 :44233665|FS of Child2 :4
#
# Thread 25703641 Generation 3 |Child1 :15703640|FS of Child1: 6|Child2 :15703641|FS of Child2 :7
#
# Thread 26174035 Generation 2 |Child1 :05134737|FS of Child1: 3|Child2 :52374737|FS of Child2 :3
#
# Thread 24730615 Generation 8 |Child1 :44235635|FS of Child1: 4|Child2 :34233615|FS of Child2 :5
#
# Thread 05726314 Generation 13 |Child1 :01720414|FS of Child1: 5|Child2 :04726614|FS of Child2 :6
#
# Thread 15063724 Generation 10 |Child1 :17066727|FS of Child1: 5|Child2 :15066227|FS of Child2 :5
#
# Thread 25147063 Generation 4 |Child1 :26140260|FS of Child1: 4|Child2 :23145261|FS of Child2 :4
# Thread 25713064 Generation 3 |Child1 :01013014|FS of Child1: 4|Child2 :40733034|FS of Child2 :4
#
# Thread 17502463 Generation 9 |Child1 :77501461|FS of Child1: 5|Child2 :74501465|FS of Child2 :4
#
# Thread 14602753 Generation 7 |Child1 :54702765|FS of Child1: 4|Child2 :54302716|FS of Child2 :4
#
# Thread 05726314 Generation 14 |Child1 :04727414|FS of Child1: 5|Child2 :02726614|FS of Child2 :6
#
# Thread 26175304 Generation 3 |Child1 :26117004|FS of Child1: 5|Child2 :36115252|FS of Child2 :3
#
#
# Thread 05726314 Generation 15 |Child1 :02726544|FS of Child1: 5|Child2 :01726614|FS of Child2 :6
#
# Thread 06471352 Generation 15 |Child1 :06431657|FS of Child1: 5|Child2 :36467357|FS of Child2 :4
#
# Thread 24170635 Generation 7 |Child1 :24170671|FS of Child1: 6|Child2 :24150554|FS of Child2 :4
#
# Thread 24175360 Generation 9 |Child1 :04175300|FS of Child1: 6|Child2 :04130300|FS of Child2 :4
#
# Thread 27360514 Generation 3 |Child1 :20316224|FS of Child1: 3|Child2 :20466530|FS of Child2 :3
#
# Thread 24170635 Generation 8 |Child1 :74170654|FS of Child1: 5|Child2 :24370671|FS of Child2 :5
# Thread 04752613 Generation 17 |Child1 :14752603|FS of Child1: 6|Child2 :74762603|FS of Child2 :5
# Thread 16257403 Generation 10 |Child1 :12217213|FS of Child1: 4|Child2 :17277413|FS of Child2 :5
# Thread 20647135 Generation 15 |Child1 :70737065|FS of Child1: 3|Child2 :52541635|FS of Child2 :3
# Thread 30475261 Generation 0 |Child1 :43371267|FS of Child1: 3|Child2 :50355561|FS of Child2 :4
# Thread 06357142 Generation 12 |Child1 :05377262|FS of Child1: 4|Child2 :00377612|FS of Child2 :4
#
#
#
# Thread 14630752 Generation 12 |Child1 :14133752|FS of Child1: 6|Child2 :14133753|FS of Child2 :5
#
# Thread 13572064 Generation 11 |Child1 :10571364|FS of Child1: 5|Child2 :20572064|FS of Child2 :6
#
# Thread 25160374 Generation 8 |Child1 :56163372|FS of Child1: 4|Child2 :56163370|FS of Child2 :4
#
#
# Thread 24603175 Generation 7 |Child1 :24300155|FS of Child1: 5|Child2 :24341176|FS of Child2 :4
#
# Thread 31625740 Generation 0 |Child1 :11023525|FS of Child1: 2|Child2 :31653060|FS of Child2 :4
# Thread 26174035 Generation 3 |Child1 :56474737|FS of Child1: 4|Child2 :05174727|FS of Child2 :3
#
# Thread 13572064 Generation 12 |Child1 :60572364|FS of Child1: 5|Child2 :10572062|FS of Child2 :6
#
# Thread 25704613 Generation 2 |Child1 :20344623|FS of Child1: 4|Child2 :20704613|FS of Child2 :7
#
#
# Thread 25307461 Generation 5 |Child1 :26307473|FS of Child1: 5|Child2 :26307471|FS of Child2 :6
#
# Thread 31625704 Generation 0 |Child1 :31071764|FS of Child1: 4|Child2 :70425757|FS of Child2 :3
#
# Thread 25317460 Generation 3 |Child1 :65647464|FS of Child1: 4|Child2 :67327467|FS of Child2 :4
#
# Thread 25164073 Generation 6 |Child1 :34117073|FS of Child1: 4|Child2 :34167273|FS of Child2 :4
#
# Thread 30471625 Generation 1 |Child1 :32402265|FS of Child1: 3|Child2 :31401327|FS of Child2 :4
#
# Thread 27360514 Generation 4 |Child1 :22316530|FS of Child1: 3|Child2 :20464530|FS of Child2 :3
#
#
# Thread 24175360 Generation 10 |Child1 :04175330|FS of Child1: 6|Child2 :04175303|FS of Child2 :5
#
#
# Thread 06471352 Generation 16 |Child1 :06731357|FS of Child1: 5|Child2 :56461357|FS of Child2 :5
#
# Thread 16257403 Generation 11 |Child1 :17277413|FS of Child1: 5|Child2 :13217413|FS of Child2 :5
#
# Thread 15720364 Generation 11 |Child1 :14760161|FS of Child1: 4|Child2 :14560765|FS of Child2 :3
# Thread 05726314 Generation 16 |Child1 :01726510|FS of Child1: 5|Child2 :04726634|FS of Child2 :5
#
# Thread 24603175 Generation 8 |Child1 :24301276|FS of Child1: 4|Child2 :24345155|FS of Child2 :4
#
# Thread 25160374 Generation 9 |Child1 :56163175|FS of Child1: 3|Child2 :56463370|FS of Child2 :3
#
# Thread 14630752 Generation 13 |Child1 :14133752|FS of Child1: 6|Child2 :14233752|FS of Child2 :6
#
#
# Thread 25147063 Generation 5 |Child1 :13147517|FS of Child1: 3|Child2 :25145261|FS of Child2 :5
# Thread 25703641 Generation 4 |Child1 :15703240|FS of Child1: 5|Child2 :15700641|FS of Child2 :6
#
# Thread 26175304 Generation 4 |Child1 :26115254|FS of Child1: 5|Child2 :26117204|FS of Child2 :5
#
#
# Thread 26175304 Generation 5 |Child1 :26113254|FS of Child1: 4|Child2 :26147204|FS of Child2 :5
#
# Thread 31625740 Generation 1 |Child1 :31653760|FS of Child1: 5|Child2 :51723060|FS of Child2 :3
#
# Thread 24175360 Generation 11 |Child1 :04275300|FS of Child1: 5|Child2 :04155330|FS of Child2 :5
#
# Thread 31640752 Generation 0 |Child1 :43615742|FS of Child1: 3|Child2 :51134153|FS of Child2 :2
#
# Thread 20647135 Generation 16 |Child1 :70737035|FS of Child1: 4|Child2 :30507335|FS of Child2 :4
#
# Thread 27360514 Generation 5 |Child1 :23314530|FS of Child1: 3|Child2 :20436530|FS of Child2 :2
#
# Thread 24603175 Generation 9 |Child1 :24305135|FS of Child1: 5|Child2 :24340125|FS of Child2 :4
#
# Thread 31625704 Generation 1 |Child1 :72421764|FS of Child1: 3|Child2 :31271764|FS of Child2 :4
#
# Thread 31475026 Generation 0 |Child1 :21720276|FS of Child1: 2|Child2 :30475016|FS of Child2 :6
#
# Thread 14602753 Generation 8 |Child1 :53302766|FS of Child1: 3|Child2 :44272716|FS of Child2 :3
#
# Thread 17502463 Generation 10 |Child1 :77501460|FS of Child1: 5|Child2 :47501461|FS of Child2 :5
#
# Thread 13572064 Generation 13 |Child1 :20572064|FS of Child1: 6|Child2 :20572067|FS of Child2 :5
#
# Thread 25164073 Generation 7 |Child1 :34167077|FS of Child1: 4|Child2 :54167073|FS of Child2 :5
#
# Thread 25704613 Generation 3 |Child1 :20704213|FS of Child1: 6|Child2 :20644613|FS of Child2 :5
#
# Thread 24730615 Generation 9 |Child1 :34235635|FS of Child1: 4|Child2 :34203615|FS of Child2 :4
#
# Thread 24603175 Generation 10 |Child1 :24301155|FS of Child1: 5|Child2 :24305105|FS of Child2 :5
#
# Thread 15720364 Generation 12 |Child1 :14560661|FS of Child1: 3|Child2 :44710761|FS of Child2 :3
#
# Thread 25317460 Generation 4 |Child1 :67327414|FS of Child1: 3|Child2 :64647467|FS of Child2 :3
#
# Thread 31625740 Generation 2 |Child1 :41653060|FS of Child1: 3|Child2 :41653760|FS of Child2 :4
#
# Thread 14630752 Generation 14 |Child1 :14233752|FS of Child1: 6|Child2 :14133752|FS of Child2 :6
#
# Thread 25713064 Generation 4 |Child1 :05713034|FS of Child1: 6|Child2 :43733034|FS of Child2 :4
# Thread 16470352 Generation 8 |Child1 :76405312|FS of Child1: 4|Child2 :76720312|FS of Child2 :4
#
# Thread 06357142 Generation 13 |Child1 :00577012|FS of Child1: 3|Child2 :00147612|FS of Child2 :3
#
#
# Thread 24730615 Generation 10 |Child1 :74233615|FS of Child1: 5|Child2 :24203615|FS of Child2 :5
# Thread 14602753 Generation 9 |Child1 :54502766|FS of Child1: 4|Child2 :14672766|FS of Child2 :5
#
# Thread 06471352 Generation 17 |Child1 :06331357|FS of Child1: 5|Child2 :16461357|FS of Child2 :5
#
# Thread 04752613 Generation 18 |Child1 :04752004|FS of Child1: 5|Child2 :04752103|FS of Child2 :6
#
# Thread 26175304 Generation 6 |Child1 :26147302|FS of Child1: 5|Child2 :36177204|FS of Child2 :5
#
# Thread 05726314 Generation 17 |Child1 :01726314|FS of Child1: 7|Child2 :01706514|FS of Child2 :5
#
# Thread 31640752 Generation 1 |Child1 :32504153|FS of Child1: 2|Child2 :43340357|FS of Child2 :3
#
# Thread 25164073 Generation 8 |Child1 :54167073|FS of Child1: 5|Child2 :54167073|FS of Child2 :5
#
# Thread 15063724 Generation 11 |Child1 :15066722|FS of Child1: 6|Child2 :15066227|FS of Child2 :5
#
#
# Thread 16257403 Generation 12 |Child1 :13217713|FS of Child1: 4|Child2 :17277403|FS of Child2 :6
#
# Thread 25703641 Generation 5 |Child1 :15700642|FS of Child1: 5|Child2 :15703041|FS of Child2 :6
#
# Thread 31746025 Generation 0 |Child1 :31074527|FS of Child1: 3|Child2 :37726020|FS of Child2 :5
#
#
# Thread 31475026 Generation 1 |Child1 :30475026|FS of Child1: 7|Child2 :51725026|FS of Child2 :5
#
# Thread 24175360 Generation 12 |Child1 :04175430|FS of Child1: 5|Child2 :04575300|FS of Child2 :5
# Thread 14630752 Generation 15 |Child1 :14433752|FS of Child1: 6|Child2 :14233757|FS of Child2 :5
#
# Thread 05726314 Generation 18 |Child1 :01726614|FS of Child1: 6|Child2 :01716314|FS of Child2 :6
#
# Thread 04752613 Generation 19 |Child1 :03752103|FS of Child1: 5|Child2 :04752603|FS of Child2 :7
# Thread 25713064 Generation 5 |Child1 :05713034|FS of Child1: 6|Child2 :01713032|FS of Child2 :4
#
# Thread 25307461 Generation 6 |Child1 :26307473|FS of Child1: 5|Child2 :26307411|FS of Child2 :6
# Thread 30475261 Generation 1 |Child1 :70355361|FS of Child1: 4|Child2 :73375561|FS of Child2 :4
# Thread 24170635 Generation 9 |Child1 :24170654|FS of Child1: 6|Child2 :22170671|FS of Child2 :5
# Thread 31625704 Generation 2 |Child1 :41271764|FS of Child1: 3|Child2 :31071264|FS of Child2 :3
# Thread 17502463 Generation 11 |Child1 :47501470|FS of Child1: 4|Child2 :77531461|FS of Child2 :4
#
# Thread 16257403 Generation 13 |Child1 :17277413|FS of Child1: 5|Child2 :15217403|FS of Child2 :6
# Thread 26174035 Generation 4 |Child1 :56474037|FS of Child1: 5|Child2 :56304737|FS of Child2 :3
# Thread 20647135 Generation 17 |Child1 :30507535|FS of Child1: 4|Child2 :33507335|FS of Child2 :3
#
#
#
# Thread 25164073 Generation 9 |Child1 :54167073|FS of Child1: 5|Child2 :34157073|FS of Child2 :4
# Thread 06357142 Generation 14 |Child1 :03257662|FS of Child1: 4|Child2 :00347462|FS of Child2 :4
#
# Thread 24603175 Generation 11 |Child1 :54301155|FS of Child1: 4|Child2 :24305305|FS of Child2 :4
#
#
# Thread 05726314 Generation 19 |Child1 :01726714|FS of Child1: 6|Child2 :01756314|FS of Child2 :6
#
#
# Thread 15063724 Generation 12 |Child1 :15066722|FS of Child1: 6|Child2 :15066720|FS of Child2 :6
#
# Thread 25703641 Generation 6 |Child1 :25703041|FS of Child1: 7|Child2 :45703641|FS of Child2 :7
#
# Thread 30471625 Generation 2 |Child1 :31401327|FS of Child1: 4|Child2 :70417327|FS of Child2 :3
#
# Thread 16470352 Generation 9 |Child1 :76400312|FS of Child1: 5|Child2 :76420312|FS of Child2 :5
#
# Thread 25713064 Generation 6 |Child1 :05712034|FS of Child1: 5|Child2 :05710034|FS of Child2 :5
#
# Thread 24730615 Generation 11 |Child1 :20203615|FS of Child1: 4|Child2 :74233615|FS of Child2 :5
#
# Thread 27360514 Generation 6 |Child1 :27316222|FS of Child1: 3|Child2 :20066530|FS of Child2 :3
# Thread 25147063 Generation 6 |Child1 :75147517|FS of Child1: 4|Child2 :21145261|FS of Child2 :4
#
# Thread 13572064 Generation 14 |Child1 :10512064|FS of Child1: 6|Child2 :25572364|FS of Child2 :5
#
#
# Thread 05726314 Generation 20 |Child1 :01727314|FS of Child1: 6|Child2 :01750314|FS of Child2 :5
#
# Thread 31625740 Generation 3 |Child1 :31053760|FS of Child1: 4|Child2 :41653760|FS of Child2 :4
#
#
# Thread 15720364 Generation 13 |Child1 :15040761|FS of Child1: 4|Child2 :15300162|FS of Child2 :4
#
#
# Thread 20647135 Generation 18 |Child1 :50307635|FS of Child1: 4|Child2 :00207035|FS of Child2 :4
#
# Thread 31750246 Generation 0 |Child1 :51440665|FS of Child1: 2|Child2 :30750246|FS of Child2 :7
#
# Thread 25704613 Generation 4 |Child1 :20704214|FS of Child1: 5|Child2 :20104613|FS of Child2 :6
#
# Thread 16257403 Generation 14 |Child1 :15217400|FS of Child1: 5|Child2 :17273403|FS of Child2 :5
#
#
# Thread 15720364 Generation 14 |Child1 :15000162|FS of Child1: 4|Child2 :15640162|FS of Child2 :4
#
# Thread 24603175 Generation 12 |Child1 :24345105|FS of Child1: 4|Child2 :24300155|FS of Child2 :5
#
# Thread 31475026 Generation 2 |Child1 :30475066|FS of Child1: 6|Child2 :30435026|FS of Child2 :6
#
# Thread 25317460 Generation 5 |Child1 :64027467|FS of Child1: 3|Child2 :61347467|FS of Child2 :4
#
#
# Thread 31640752 Generation 2 |Child1 :43341622|FS of Child1: 2|Child2 :21610357|FS of Child2 :4
#
# Thread 35041726 Generation 0 |Child1 :62051323|FS of Child1: 3|Child2 :30001246|FS of Child2 :4
#
#
# Thread 31746025 Generation 1 |Child1 :37720020|FS of Child1: 4|Child2 :31076320|FS of Child2 :4
#
# Thread 25160374 Generation 10 |Child1 :20663370|FS of Child1: 4|Child2 :26266070|FS of Child2 :3
#
# Thread 25160374 Generation 11 |Child1 :56163365|FS of Child1: 3|Child2 :55163375|FS of Child2 :5
# Thread 06471352 Generation 18 |Child1 :06431057|FS of Child1: 5|Child2 :16461357|FS of Child2 :5
# Thread 20647135 Generation 19 |Child1 :00257035|FS of Child1: 4|Child2 :70737045|FS of Child2 :3
# Thread 26175304 Generation 7 |Child1 :36177304|FS of Child1: 6|Child2 :36110204|FS of Child2 :4
#
# Thread 04752613 Generation 20 |Child1 :04754603|FS of Child1: 6|Child2 :04752503|FS of Child2 :6
#
#
# Thread 15063724 Generation 13 |Child1 :15064722|FS of Child1: 6|Child2 :65066720|FS of Child2 :5
# Thread 30475261 Generation 2 |Child1 :73375661|FS of Child1: 4|Child2 :70355361|FS of Child2 :4
# Thread 16257403 Generation 15 |Child1 :15217303|FS of Child1: 5|Child2 :17272403|FS of Child2 :5
#
# Thread 24730615 Generation 12 |Child1 :76233615|FS of Child1: 4|Child2 :24273615|FS of Child2 :5
# Thread 14630752 Generation 16 |Child1 :14133652|FS of Child1: 5|Child2 :14133552|FS of Child2 :5
# Thread 35716024 Generation 0 |Child1 :30014322|FS of Child1: 3|Child2 :75737024|FS of Child2 :5
#
# Thread 31750246 Generation 1 |Child1 :30750446|FS of Child1: 6|Child2 :51442246|FS of Child2 :4
# Thread 35716024 Generation 1 |Child1 :75730322|FS of Child1: 3|Child2 :65737024|FS of Child2 :5
#
# Thread 25713064 Generation 7 |Child1 :75713034|FS of Child1: 6|Child2 :05513034|FS of Child2 :5
#
# Thread 16257403 Generation 16 |Child1 :25217403|FS of Child1: 5|Child2 :17277403|FS of Child2 :6
#
# Thread 25147063 Generation 7 |Child1 :25145461|FS of Child1: 5|Child2 :21645261|FS of Child2 :3
#
# Thread 36074152 Generation 0 |Child1 :56053350|FS of Child1: 3|Child2 :45674056|FS of Child2 :3
#
# Thread 16470352 Generation 10 |Child1 :76425312|FS of Child1: 4|Child2 :76400312|FS of Child2 :5
#
# Thread 25164073 Generation 10 |Child1 :54164073|FS of Child1: 6|Child2 :54667073|FS of Child2 :4
# Thread 27360514 Generation 7 |Child1 :17316530|FS of Child1: 3|Child2 :26066530|FS of Child2 :3
#
#
#
# Thread 31475026 Generation 3 |Child1 :60475026|FS of Child1: 6|Child2 :30035026|FS of Child2 :5
# Thread 26175304 Generation 8 |Child1 :36175374|FS of Child1: 6|Child2 :40117304|FS of Child2 :4
#
#
#
#
# Thread 06357142 Generation 15 |Child1 :00147612|FS of Child1: 3|Child2 :00377466|FS of Child2 :3
# Thread 31640752 Generation 3 |Child1 :21611620|FS of Child1: 2|Child2 :71610357|FS of Child2 :4
#
#
#
#
#
# Thread 06471352 Generation 19 |Child1 :06631357|FS of Child1: 5|Child2 :16461157|FS of Child2 :4
#
# Thread 04752613 Generation 21 |Child1 :06752603|FS of Child1: 6|Child2 :04752603|FS of Child2 :7
#
# Thread 31625740 Generation 4 |Child1 :31653766|FS of Child1: 4|Child2 :41653762|FS of Child2 :3
#
# Thread 14602753 Generation 10 |Child1 :14673765|FS of Child1: 4|Child2 :54752766|FS of Child2 :3
#
# Thread 26174035 Generation 5 |Child1 :56574737|FS of Child1: 4|Child2 :05170037|FS of Child2 :4
# Thread 31625704 Generation 3 |Child1 :31054764|FS of Child1: 4|Child2 :01275757|FS of Child2 :3
# Thread 25703641 Generation 7 |Child1 :45703041|FS of Child1: 6|Child2 :15003641|FS of Child2 :6
# Thread 30471625 Generation 3 |Child1 :70412327|FS of Child1: 3|Child2 :31451327|FS of Child2 :4
#
# Thread 16257403 Generation 17 |Child1 :47277403|FS of Child1: 5|Child2 :07277403|FS of Child2 :5
#
#
# Thread 17502463 Generation 12 |Child1 :47201460|FS of Child1: 4|Child2 :77501461|FS of Child2 :5
# Thread 35041726 Generation 1 |Child1 :30001323|FS of Child1: 4|Child2 :37001246|FS of Child2 :4
#
# Thread 31746025 Generation 2 |Child1 :37726020|FS of Child1: 5|Child2 :31076020|FS of Child2 :5
#
#
# Thread 25713064 Generation 8 |Child1 :05753034|FS of Child1: 5|Child2 :75703034|FS of Child2 :5
#
#
#
# Thread 25164073 Generation 11 |Child1 :54567073|FS of Child1: 4|Child2 :54464073|FS of Child2 :5
#
# Thread 25307461 Generation 7 |Child1 :66307471|FS of Child1: 5|Child2 :46307411|FS of Child2 :5
#
# Thread 35041726 Generation 2 |Child1 :37101323|FS of Child1: 3|Child2 :30301246|FS of Child2 :3
#
# Thread 25704613 Generation 5 |Child1 :20704643|FS of Child1: 6|Child2 :20204613|FS of Child2 :6
#
#
# Thread 05726314 Generation 21 |Child1 :01722514|FS of Child1: 5|Child2 :04726214|FS of Child2 :6
#
# Thread 13572064 Generation 15 |Child1 :20572367|FS of Child1: 4|Child2 :10572064|FS of Child2 :7
#
# Thread 15720364 Generation 15 |Child1 :35640761|FS of Child1: 3|Child2 :15640163|FS of Child2 :4
#
# Thread 13572064 Generation 16 |Child1 :15572064|FS of Child1: 7|Child2 :12512064|FS of Child2 :6
#
# Thread 17502463 Generation 13 |Child1 :77701461|FS of Child1: 4|Child2 :27501461|FS of Child2 :5
#
# Thread 24170635 Generation 10 |Child1 :24140654|FS of Child1: 5|Child2 :24170631|FS of Child2 :7
#
# Thread 24603175 Generation 13 |Child1 :24305005|FS of Child1: 4|Child2 :24307155|FS of Child2 :5
#
# Thread 14602753 Generation 11 |Child1 :14672767|FS of Child1: 5|Child2 :44672666|FS of Child2 :3
# Thread 16470352 Generation 11 |Child1 :76400212|FS of Child1: 4|Child2 :76440312|FS of Child2 :5
#
# Thread 31640752 Generation 4 |Child1 :71610307|FS of Child1: 3|Child2 :21610350|FS of Child2 :4
#
# Thread 26175304 Generation 9 |Child1 :26177304|FS of Child1: 7|Child2 :36175354|FS of Child2 :6
#
# Thread 25147063 Generation 8 |Child1 :25145561|FS of Child1: 5|Child2 :25145463|FS of Child2 :6
#
# Thread 05726314 Generation 22 |Child1 :01756214|FS of Child1: 5|Child2 :04726312|FS of Child2 :6
#
# Thread 25307461 Generation 8 |Child1 :26107471|FS of Child1: 5|Child2 :06307411|FS of Child2 :5
# Thread 31475026 Generation 4 |Child1 :30275026|FS of Child1: 6|Child2 :61475026|FS of Child2 :7
#
# Thread 16257403 Generation 18 |Child1 :17677403|FS of Child1: 5|Child2 :17177403|FS of Child2 :5
#
# Thread 31625740 Generation 5 |Child1 :31653736|FS of Child1: 4|Child2 :33653760|FS of Child2 :4
#
# Thread 25704613 Generation 6 |Child1 :20704613|FS of Child1: 7|Child2 :20204613|FS of Child2 :6
#
# Thread 25147063 Generation 9 |Child1 :25145161|FS of Child1: 5|Child2 :25145467|FS of Child2 :5
#
# Thread 30471625 Generation 4 |Child1 :31052225|FS of Child1: 3|Child2 :34401326|FS of Child2 :4
#
#
# Thread 25160374 Generation 12 |Child1 :55363370|FS of Child1: 4|Child2 :57163375|FS of Child2 :4
#
# Thread 25164073 Generation 12 |Child1 :54164074|FS of Child1: 5|Child2 :54464573|FS of Child2 :4
# Thread 25703641 Generation 8 |Child1 :15723641|FS of Child1: 6|Child2 :45703601|FS of Child2 :6
#
# Thread 24175360 Generation 13 |Child1 :04175530|FS of Child1: 5|Child2 :04173300|FS of Child2 :5
#
# Thread 24730615 Generation 13 |Child1 :21273615|FS of Child1: 4|Child2 :44233615|FS of Child2 :5
#
# Thread 14630752 Generation 17 |Child1 :14131752|FS of Child1: 6|Child2 :04433752|FS of Child2 :5
#
# Thread 20647135 Generation 20 |Child1 :70737631|FS of Child1: 3|Child2 :70367035|FS of Child2 :4
#
# Thread 31746025 Generation 3 |Child1 :41076020|FS of Child1: 4|Child2 :37626020|FS of Child2 :4
#
# Thread 06471352 Generation 20 |Child1 :00431357|FS of Child1: 5|Child2 :16461657|FS of Child2 :4
#
# Thread 30475261 Generation 3 |Child1 :70355321|FS of Child1: 3|Child2 :74375361|FS of Child2 :4
# Thread 24603175 Generation 14 |Child1 :24305105|FS of Child1: 5|Child2 :24307154|FS of Child2 :4
#
# Thread 06357142 Generation 16 |Child1 :00077062|FS of Child1: 3|Child2 :00375712|FS of Child2 :3
#
# Thread 27360514 Generation 8 |Child1 :27356530|FS of Child1: 4|Child2 :26066530|FS of Child2 :3
#
#
# Thread 35041726 Generation 3 |Child1 :37301323|FS of Child1: 3|Child2 :30001206|FS of Child2 :4
#
# Thread 06357142 Generation 17 |Child1 :05377062|FS of Child1: 4|Child2 :00347012|FS of Child2 :4
#
# Thread 31625740 Generation 6 |Child1 :31353760|FS of Child1: 4|Child2 :37653760|FS of Child2 :4
#
# Thread 13572064 Generation 17 |Child1 :15572564|FS of Child1: 6|Child2 :10572064|FS of Child2 :7
#
# Thread 31746025 Generation 4 |Child1 :31276020|FS of Child1: 5|Child2 :01076020|FS of Child2 :4
#
# Thread 36271405 Generation 0 |Child1 :31701454|FS of Child1: 3|Child2 :61211604|FS of Child2 :3
#
# Thread 31750246 Generation 2 |Child1 :30750445|FS of Child1: 5|Child2 :60750246|FS of Child2 :6
#
# Thread 36415027 Generation 0 |Child1 :23215520|FS of Child1: 3|Child2 :33706027|FS of Child2 :4
#
# Thread 26174035 Generation 6 |Child1 :56410037|FS of Child1: 3|Child2 :05144037|FS of Child2 :4
#
# Thread 25307461 Generation 9 |Child1 :22307471|FS of Child1: 6|Child2 :26307411|FS of Child2 :6
#
#
# Thread 25317460 Generation 6 |Child1 :61347664|FS of Child1: 3|Child2 :65646467|FS of Child2 :3
#
# Thread 30471625 Generation 5 |Child1 :34402226|FS of Child1: 3|Child2 :34401326|FS of Child2 :4
#
# Thread 24175360 Generation 14 |Child1 :04125300|FS of Child1: 5|Child2 :04115300|FS of Child2 :5
#
# Thread 25307461 Generation 10 |Child1 :26305471|FS of Child1: 5|Child2 :22307411|FS of Child2 :6
#
# Thread 16470352 Generation 12 |Child1 :76440365|FS of Child1: 4|Child2 :76450312|FS of Child2 :5
#
# Thread 31640752 Generation 5 |Child1 :21510357|FS of Child1: 3|Child2 :71617350|FS of Child2 :3
#
# Thread 25703641 Generation 9 |Child1 :15703641|FS of Child1: 7|Child2 :25700641|FS of Child2 :7
#
# Thread 25160374 Generation 13 |Child1 :55163370|FS of Child1: 5|Child2 :57165375|FS of Child2 :4
#
# Thread 25713064 Generation 9 |Child1 :35713034|FS of Child1: 6|Child2 :75713034|FS of Child2 :6
# Thread 31625704 Generation 4 |Child1 :01624760|FS of Child1: 4|Child2 :31051203|FS of Child2 :3
# Thread 31750246 Generation 3 |Child1 :30710246|FS of Child1: 6|Child2 :60750246|FS of Child2 :6
#
#
# Thread 24603175 Generation 15 |Child1 :24305205|FS of Child1: 4|Child2 :04301155|FS of Child2 :4
#
# Thread 26175304 Generation 10 |Child1 :26171354|FS of Child1: 6|Child2 :36137304|FS of Child2 :5
#
# Thread 24170635 Generation 11 |Child1 :24370654|FS of Child1: 5|Child2 :21170631|FS of Child2 :6
#
# Thread 26174035 Generation 7 |Child1 :54474037|FS of Child1: 4|Child2 :05174037|FS of Child2 :5
#
# Thread 04752613 Generation 22 |Child1 :07752603|FS of Child1: 6|Child2 :04152603|FS of Child2 :6
#
# Thread 36420571 Generation 0 |Child1 :50420753|FS of Child1: 3|Child2 :16124571|FS of Child2 :5
#
# Thread 20647135 Generation 21 |Child1 :70767035|FS of Child1: 4|Child2 :71407035|FS of Child2 :3
#
# Thread 15720364 Generation 16 |Child1 :15240761|FS of Child1: 4|Child2 :15240163|FS of Child2 :4
#
# Thread 24175360 Generation 15 |Child1 :04175300|FS of Child1: 6|Child2 :74175330|FS of Child2 :6
#
# Thread 06357142 Generation 18 |Child1 :00447612|FS of Child1: 3|Child2 :04377012|FS of Child2 :4
#
# Thread 25704613 Generation 7 |Child1 :20704613|FS of Child1: 7|Child2 :50704613|FS of Child2 :6
#
# Thread 05726314 Generation 23 |Child1 :01326312|FS of Child1: 5|Child2 :04726314|FS of Child2 :7
#
# Thread 25703641 Generation 10 |Child1 :25703241|FS of Child1: 7|Child2 :15700641|FS of Child2 :6
#
# Thread 31746025 Generation 5 |Child1 :31576020|FS of Child1: 5|Child2 :71076020|FS of Child2 :4
# Thread 36271405 Generation 1 |Child1 :31751454|FS of Child1: 3|Child2 :60211604|FS of Child2 :3
# Thread 30471625 Generation 6 |Child1 :36401326|FS of Child1: 4|Child2 :34401321|FS of Child2 :4
#
# Thread 30471625 Generation 7 |Child1 :34401326|FS of Child1: 4|Child2 :36201321|FS of Child2 :3
# Thread 31750246 Generation 4 |Child1 :30750247|FS of Child1: 6|Child2 :60750276|FS of Child2 :5
# Thread 04752613 Generation 23 |Child1 :04752503|FS of Child1: 6|Child2 :04750603|FS of Child2 :6
#
#
# Thread 36415027 Generation 1 |Child1 :33706007|FS of Child1: 3|Child2 :23216127|FS of Child2 :3
#
# Thread 25160374 Generation 14 |Child1 :55163775|FS of Child1: 4|Child2 :57163370|FS of Child2 :4
#
#
#
# Thread 14602753 Generation 12 |Child1 :44672766|FS of Child1: 4|Child2 :14672760|FS of Child2 :5
# Thread 06471352 Generation 21 |Child1 :06431357|FS of Child1: 6|Child2 :66431357|FS of Child2 :5
#
# Thread 31625740 Generation 7 |Child1 :31653765|FS of Child1: 4|Child2 :37633760|FS of Child2 :4
#
# Thread 25164073 Generation 13 |Child1 :51167073|FS of Child1: 5|Child2 :34164773|FS of Child2 :5
#
# Thread 13572064 Generation 18 |Child1 :10572067|FS of Child1: 6|Child2 :15572063|FS of Child2 :6
#
# Thread 26174035 Generation 8 |Child1 :05174737|FS of Child1: 4|Child2 :56474017|FS of Child2 :4
#
# Thread 06357142 Generation 19 |Child1 :04376612|FS of Child1: 3|Child2 :50377012|FS of Child2 :3
#
# Thread 31625740 Generation 8 |Child1 :31613760|FS of Child1: 5|Child2 :37633764|FS of Child2 :3
#
# Thread 31640752 Generation 6 |Child1 :01610357|FS of Child1: 4|Child2 :71660350|FS of Child2 :4
#
# Thread 24170635 Generation 12 |Child1 :24670631|FS of Child1: 6|Child2 :24170631|FS of Child2 :7
#
# Thread 35720641 Generation 0 |Child1 :32271661|FS of Child1: 3|Child2 :75460607|FS of Child2 :3
#
#
# Thread 15063724 Generation 14 |Child1 :15060723|FS of Child1: 6|Child2 :15046727|FS of Child2 :5
#
# Thread 25317460 Generation 7 |Child1 :65747467|FS of Child1: 4|Child2 :61343467|FS of Child2 :3
#
# Thread 17502463 Generation 14 |Child1 :27501466|FS of Child1: 5|Child2 :47521461|FS of Child2 :4
#
# Thread 16257403 Generation 19 |Child1 :17217403|FS of Child1: 6|Child2 :11277403|FS of Child2 :6
#
# Thread 14630752 Generation 18 |Child1 :14131752|FS of Child1: 6|Child2 :14133252|FS of Child2 :5
# Thread 16470352 Generation 13 |Child1 :76450352|FS of Child1: 6|Child2 :76420112|FS of Child2 :4
# Thread 35716024 Generation 2 |Child1 :25737024|FS of Child1: 5|Child2 :75737020|FS of Child2 :4
# Thread 24730615 Generation 14 |Child1 :44233115|FS of Child1: 4|Child2 :24272615|FS of Child2 :5
# Thread 36420571 Generation 1 |Child1 :16124575|FS of Child1: 4|Child2 :51424571|FS of Child2 :5
#
# Thread 36420571 Generation 2 |Child1 :51424577|FS of Child1: 4|Child2 :16124511|FS of Child2 :4
#
#
#
#
# Thread 15720364 Generation 17 |Child1 :15210761|FS of Child1: 4|Child2 :15640133|FS of Child2 :3
#
#
# Thread 27360514 Generation 9 |Child1 :27356530|FS of Child1: 4|Child2 :27116530|FS of Child2 :3
#
#
# Thread 35041726 Generation 4 |Child1 :30002246|FS of Child1: 3|Child2 :37051206|FS of Child2 :4
#
# Thread 04752613 Generation 24 |Child1 :04752003|FS of Child1: 6|Child2 :04352603|FS of Child2 :6
#
#
#
# Thread 26174035 Generation 9 |Child1 :02174037|FS of Child1: 5|Child2 :56474437|FS of Child2 :4
#
# Thread 30475261 Generation 4 |Child1 :74375361|FS of Child1: 4|Child2 :73375361|FS of Child2 :4
# Thread 25713064 Generation 10 |Child1 :75711034|FS of Child1: 5|Child2 :35773034|FS of Child2 :5
#
# Thread 31640752 Generation 7 |Child1 :01660357|FS of Child1: 4|Child2 :01630350|FS of Child2 :4
#
# ...
#
# Thread 25160374 Generation 15 |Child1 :55163373|FS of Child1: 5|Child2 :52163370|FS of Child2 :4
#
# Thread 20647135 Generation 23 |Child1 :52747035|FS of Child1: 4|Child2 :70707035|FS of Child2 :4
#
# Thread 25703641 Generation 11 |Child1 :15703221|FS of Child1: 5|Child2 :25703741|FS of Child2 :7
#
# Thread 06357142 Generation 20 |Child1 :07347062|FS of Child1: 4|Child2 :07377012|FS of Child2 :4
#
# Thread 25317460 Generation 8 |Child1 :75647467|FS of Child1: 4|Child2 :61747464|FS of Child2 :3
#
# Thread 36074152 Generation 1 |Child1 :56051056|FS of Child1: 3|Child2 :42674056|FS of Child2 :3
#
# Thread 31625704 Generation 5 |Child1 :01621762|FS of Child1: 4|Child2 :31071073|FS of Child2 :2
# Thread 25164073 Generation 14 |Child1 :54164743|FS of Child1: 4|Child2 :34164073|FS of Child2 :6
#
# Thread 05726314 Generation 24 |Child1 :04726314|FS of Child1: 7|Child2 :01726344|FS of Child2 :6
# Thread 24730615 Generation 15 |Child1 :24273615|FS of Child1: 5|Child2 :44432615|FS of Child2 :5
#
# Thread 24603175 Generation 16 |Child1 :24305104|FS of Child1: 4|Child2 :74301155|FS of Child2 :4
#
# Thread 35720641 Generation 1 |Child1 :75460412|FS of Child1: 2|Child2 :33670407|FS of Child2 :2
#
# Thread 26175304 Generation 11 |Child1 :26671354|FS of Child1: 5|Child2 :26177374|FS of Child2 :6
#
# Thread 36420571 Generation 3 |Child1 :51424571|FS of Child1: 5|Child2 :16124521|FS of Child2 :4
# Thread 26174035 Generation 10 |Child1 :56472037|FS of Child1: 4|Child2 :02177037|FS of Child2 :4
#
# Thread 31750246 Generation 5 |Child1 :31750247|FS of Child1: 7|Child2 :30250246|FS of Child2 :6
#
# Thread 16257403 Generation 20 |Child1 :11477403|FS of Child1: 5|Child2 :17417403|FS of Child2 :5
#
# Thread 25160374 Generation 16 |Child1 :55163370|FS of Child1: 5|Child2 :55153373|FS of Child2 :4
#
# Thread 31625740 Generation 9 |Child1 :31213760|FS of Child1: 4|Child2 :31603760|FS of Child2 :5
#
# Thread 17502463 Generation 16 |Child1 :67501461|FS of Child1: 5|Child2 :75501461|FS of Child2 :4
#
# Thread 36415027 Generation 2 |Child1 :23316027|FS of Child1: 4|Child2 :33705027|FS of Child2 :5
# Thread 35716024 Generation 3 |Child1 :25737524|FS of Child1: 4|Child2 :65737022|FS of Child2 :4
#
# Thread 20647135 Generation 24 |Child1 :70707236|FS of Child1: 3|Child2 :70307635|FS of Child2 :4
#
#
# Thread 40731625 Generation 0 |Child1 :40053221|FS of Child1: 3|Child2 :64730605|FS of Child2 :4
#
#
# Thread 37025164 Generation 1 |Child1 :30034624|FS of Child1: 3|Child2 :37032567|FS of Child2 :4
#
# Thread 15720364 Generation 18 |Child1 :15640161|FS of Child1: 4|Child2 :17760162|FS of Child2 :4
#
# Thread 36271405 Generation 2 |Child1 :31771464|FS of Child1: 4|Child2 :66211624|FS of Child2 :3
#
# Thread 31746025 Generation 6 |Child1 :37736020|FS of Child1: 5|Child2 :11076020|FS of Child2 :4
#
# Thread 24730615 Generation 16 |Child1 :44733615|FS of Child1: 6|Child2 :24272612|FS of Child2 :4
#
# Thread 35720641 Generation 2 |Child1 :32275341|FS of Child1: 3|Child2 :65430667|FS of Child2 :3
#
# Thread 24603175 Generation 17 |Child1 :24305005|FS of Child1: 4|Child2 :24001155|FS of Child2 :5
#
# Thread 30471625 Generation 8 |Child1 :70411336|FS of Child1: 3|Child2 :74401327|FS of Child2 :3
#
# Thread 31750246 Generation 6 |Child1 :31750236|FS of Child1: 7|Child2 :30756247|FS of Child2 :5
#
# Thread 30475261 Generation 5 |Child1 :73175661|FS of Child1: 4|Child2 :73375365|FS of Child2 :3
#
# Thread 06471352 Generation 22 |Child1 :06431757|FS of Child1: 5|Child2 :06431357|FS of Child2 :6
#
# Thread 35716024 Generation 4 |Child1 :75727024|FS of Child1: 5|Child2 :25737024|FS of Child2 :5
#
# Thread 14630752 Generation 19 |Child1 :16131752|FS of Child1: 5|Child2 :14131752|FS of Child2 :6
#
#
# Thread 04752613 Generation 25 |Child1 :04752604|FS of Child1: 6|Child2 :04756603|FS of Child2 :6
#
# Thread 31640752 Generation 8 |Child1 :01630357|FS of Child1: 4|Child2 :01630350|FS of Child2 :4
#
# Thread 16257403 Generation 21 |Child1 :15217407|FS of Child1: 5|Child2 :11077403|FS of Child2 :5
#
#
# Thread 35041726 Generation 5 |Child1 :37051216|FS of Child1: 4|Child2 :30001206|FS of Child2 :4
# Thread 25317460 Generation 9 |Child1 :60327467|FS of Child1: 4|Child2 :67327457|FS of Child2 :3
# Thread 16470352 Generation 14 |Child1 :76450012|FS of Child1: 4|Child2 :76420357|FS of Child2 :5
#
# Thread 31475026 Generation 6 |Child1 :61435026|FS of Child1: 6|Child2 :30475022|FS of Child2 :6
#
# Thread 24170635 Generation 13 |Child1 :25170631|FS of Child1: 6|Child2 :24170331|FS of Child2 :6
#
# Thread 31625740 Generation 10 |Child1 :31603764|FS of Child1: 4|Child2 :31653761|FS of Child2 :4
#
# Thread 40357162 Generation 0 |Child1 :41305500|FS of Child1: 2|Child2 :60356166|FS of Child2 :5
#
# Thread 24730615 Generation 17 |Child1 :44733645|FS of Child1: 5|Child2 :24203625|FS of Child2 :4
#
# Thread 06357142 Generation 21 |Child1 :05377662|FS of Child1: 4|Child2 :03257012|FS of Child2 :4
#
# Thread 15720364 Generation 19 |Child1 :10760161|FS of Child1: 4|Child2 :16760162|FS of Child2 :4
#
# Thread 13572064 Generation 19 |Child1 :75572064|FS of Child1: 6|Child2 :10570064|FS of Child2 :6
#
# Thread 14602753 Generation 13 |Child1 :14672467|FS of Child1: 4|Child2 :34672760|FS of Child2 :4
# Thread 25713064 Generation 11 |Child1 :05713035|FS of Child1: 5|Child2 :05713034|FS of Child2 :6
#
# Thread 36271405 Generation 3 |Child1 :66211604|FS of Child1: 4|Child2 :31771451|FS of Child2 :4
#
#
# Thread 24175360 Generation 16 |Child1 :74575300|FS of Child1: 5|Child2 :04475330|FS of Child2 :5
#
# Thread 36074152 Generation 2 |Child1 :56254056|FS of Child1: 3|Child2 :42674356|FS of Child2 :3
#
# Thread 37025164 Generation 2 |Child1 :37033624|FS of Child1: 4|Child2 :37232567|FS of Child2 :3
#
# Thread 36074152 Generation 3 |Child1 :56054366|FS of Child1: 3|Child2 :43674056|FS of Child2 :3
# Thread 35720641 Generation 3 |Child1 :65437440|FS of Child1: 2|Child2 :36520627|FS of Child2 :4
#
# Thread 24603175 Generation 18 |Child1 :04005105|FS of Child1: 4|Child2 :24371155|FS of Child2 :4
#
# Thread 27360514 Generation 10 |Child1 :27376530|FS of Child1: 4|Child2 :27356570|FS of Child2 :4
#
# Thread 16470352 Generation 15 |Child1 :76450356|FS of Child1: 5|Child2 :26420352|FS of Child2 :6
#
# Thread 25164073 Generation 15 |Child1 :34164023|FS of Child1: 5|Child2 :54264073|FS of Child2 :5
#
# Thread 31746025 Generation 7 |Child1 :31276720|FS of Child1: 4|Child2 :31056020|FS of Child2 :5
#
#
# Thread 31750246 Generation 7 |Child1 :31710247|FS of Child1: 6|Child2 :31350236|FS of Child2 :6
# Thread 24603175 Generation 19 |Child1 :24300155|FS of Child1: 5|Child2 :24301155|FS of Child2 :5
# Thread 25160374 Generation 17 |Child1 :53163373|FS of Child1: 4|Child2 :55123370|FS of Child2 :4
# Thread 13572064 Generation 20 |Child1 :11572064|FS of Child1: 7|Child2 :13572064|FS of Child2 :8
# Thread 15720364 Generation 20 |Child1 :16760767|FS of Child1: 4|Child2 :15640362|FS of Child2 :5
# Thread 20647135 Generation 25 |Child1 :70307635|FS of Child1: 4|Child2 :70737135|FS of Child2 :5
#
# Thread 25713064 Generation 12 |Child1 :05753034|FS of Child1: 5|Child2 :05713134|FS of Child2 :5
#
# Thread 26175304 Generation 12 |Child1 :26177344|FS of Child1: 6|Child2 :26177304|FS of Child2 :7
# Thread 31640752 Generation 9 |Child1 :01636357|FS of Child1: 3|Child2 :01620350|FS of Child2 :4
#
# Thread 37420615 Generation 0 |Child1 :14322415|FS of Child1: 3|Child2 :31277316|FS of Child2 :2
#
# Thread 31625740 Generation 11 |Child1 :31403760|FS of Child1: 4|Child2 :31653720|FS of Child2 :5
#
# Thread 37046152 Generation 0 |Child1 :73046065|FS of Child1: 3|Child2 :35574552|FS of Child2 :3
#
# Thread 25703641 Generation 12 |Child1 :25703241|FS of Child1: 7|Child2 :25703747|FS of Child2 :6
#
# Thread 04752613 Generation 26 |Child1 :04752605|FS of Child1: 6|Child2 :04762603|FS of Child2 :6
#
# Thread 31475026 Generation 7 |Child1 :32475026|FS of Child1: 7|Child2 :61415026|FS of Child2 :6
#
# Thread 24175360 Generation 17 |Child1 :44175330|FS of Child1: 6|Child2 :74115300|FS of Child2 :5
#
#
# Thread 06471352 Generation 23 |Child1 :26431357|FS of Child1: 5|Child2 :06431353|FS of Child2 :6
#
# Thread 31625704 Generation 6 |Child1 :31074764|FS of Child1: 4|Child2 :31055752|FS of Child2 :4
#
# Thread 24730615 Generation 18 |Child1 :44633615|FS of Child1: 5|Child2 :04233615|FS of Child2 :5
#
# Thread 25307461 Generation 12 |Child1 :26307471|FS of Child1: 6|Child2 :26107411|FS of Child2 :5
#
# Thread 26174035 Generation 11 |Child1 :02174032|FS of Child1: 5|Child2 :56774037|FS of Child2 :5
#
#
#
# Thread 14630752 Generation 20 |Child1 :14133752|FS of Child1: 6|Child2 :14431750|FS of Child2 :5
#
# Thread 30471625 Generation 9 |Child1 :34401376|FS of Child1: 3|Child2 :34402525|FS of Child2 :4
#
# Thread 35716024 Generation 5 |Child1 :25737024|FS of Child1: 5|Child2 :25737124|FS of Child2 :4
#
# Thread 41362750 Generation 0 |Child1 :55105754|FS of Child1: 2|Child2 :30532750|FS of Child2 :4
#
# Thread 16470352 Generation 16 |Child1 :26427352|FS of Child1: 5|Child2 :76456352|FS of Child2 :5
#
#
#
# Thread 06357142 Generation 22 |Child1 :00257012|FS of Child1: 4|Child2 :04377012|FS of Child2 :4
#
# Thread 25704613 Generation 9 |Child1 :30704613|FS of Child1: 6|Child2 :20724613|FS of Child2 :6
# Thread 35041726 Generation 6 |Child1 :30002206|FS of Child1: 3|Child2 :35001206|FS of Child2 :5
#
#
# Thread 40357162 Generation 1 |Child1 :64350166|FS of Child1: 4|Child2 :41306666|FS of Child2 :3
#
# Thread 24175360 Generation 18 |Child1 :44175350|FS of Child1: 6|Child2 :04175334|FS of Child2 :5
#
# Thread 17502463 Generation 17 |Child1 :77201461|FS of Child1: 4|Child2 :67501661|FS of Child2 :4
#
# Thread 24730615 Generation 19 |Child1 :44233615|FS of Child1: 5|Child2 :04233215|FS of Child2 :4
#
# Thread 36074152 Generation 4 |Child1 :56054245|FS of Child1: 3|Child2 :02074026|FS of Child2 :3
#
# Thread 16257403 Generation 22 |Child1 :11277403|FS of Child1: 6|Child2 :17217473|FS of Child2 :5
# Thread 35720641 Generation 4 |Child1 :36572617|FS of Child1: 2|Child2 :35210627|FS of Child2 :4
#
#
#
# Thread 06471352 Generation 24 |Child1 :06436357|FS of Child1: 5|Child2 :36431353|FS of Child2 :5
#
# Thread 31746025 Generation 8 |Child1 :31056220|FS of Child1: 4|Child2 :37076020|FS of Child2 :4
#
# Thread 24170635 Generation 14 |Child1 :24070631|FS of Child1: 6|Child2 :24170671|FS of Child2 :6
#
# Thread 40731625 Generation 1 |Child1 :64731704|FS of Child1: 3|Child2 :74730605|FS of Child2 :4
#
# Thread 13572064 Generation 21 |Child1 :13572044|FS of Child1: 7|Child2 :10572064|FS of Child2 :7
#
# Thread 25147063 Generation 11 |Child1 :25115463|FS of Child1: 5|Child2 :25545463|FS of Child2 :5
#
# Thread 15063724 Generation 15 |Child1 :15061723|FS of Child1: 6|Child2 :15066327|FS of Child2 :5
#
# Thread 37046152 Generation 1 |Child1 :71044556|FS of Child1: 3|Child2 :55574552|FS of Child2 :2
#
# Thread 25160374 Generation 18 |Child1 :55163374|FS of Child1: 6|Child2 :56163370|FS of Child2 :4
#
# Thread 31640752 Generation 10 |Child1 :31620350|FS of Child1: 5|Child2 :01630350|FS of Child2 :4
#
# Thread 06471352 Generation 25 |Child1 :06434357|FS of Child1: 5|Child2 :56431357|FS of Child2 :5
#
# Thread 16470352 Generation 17 |Child1 :56420352|FS of Child1: 6|Child2 :76750352|FS of Child2 :5
#
# Thread 04752613 Generation 27 |Child1 :74752603|FS of Child1: 6|Child2 :04752003|FS of Child2 :6
#
# Thread 25713064 Generation 13 |Child1 :35733034|FS of Child1: 5|Child2 :25713034|FS of Child2 :7
# Thread 31746025 Generation 9 |Child1 :31076020|FS of Child1: 5|Child2 :31276020|FS of Child2 :5
#
# Thread 05726314 Generation 25 |Child1 :04746314|FS of Child1: 6|Child2 :04726310|FS of Child2 :6
#
#
# Thread 27360514 Generation 11 |Child1 :27356530|FS of Child1: 4|Child2 :27356576|FS of Child2 :4
#
# Thread 16257403 Generation 23 |Child1 :61277403|FS of Child1: 5|Child2 :11477403|FS of Child2 :5
# Thread 25307461 Generation 13 |Child1 :26337471|FS of Child1: 5|Child2 :26207411|FS of Child2 :5
#
# Thread 24603175 Generation 20 |Child1 :24305134|FS of Child1: 4|Child2 :24301175|FS of Child2 :6
#
#
# Thread 24175360 Generation 19 |Child1 :45175300|FS of Child1: 5|Child2 :04175550|FS of Child2 :5
#
# Thread 24170635 Generation 15 |Child1 :23170631|FS of Child1: 6|Child2 :24170630|FS of Child2 :7
# Thread 41357206 Generation 0 |Child1 :41431205|FS of Child1: 4|Child2 :66334263|FS of Child2 :2
# Thread 37420615 Generation 1 |Child1 :14326125|FS of Child1: 2|Child2 :05320316|FS of Child2 :3
# Thread 30475261 Generation 6 |Child1 :73375331|FS of Child1: 3|Child2 :70355561|FS of Child2 :4
# Thread 35041726 Generation 7 |Child1 :33001206|FS of Child1: 4|Child2 :17051206|FS of Child2 :3
#
# Thread 31475026 Generation 8 |Child1 :32475046|FS of Child1: 6|Child2 :60475026|FS of Child2 :6
#
#
#
# Thread 36271405 Generation 4 |Child1 :33771454|FS of Child1: 4|Child2 :76211451|FS of Child2 :4
#
# Thread 25160374 Generation 19 |Child1 :55163373|FS of Child1: 5|Child2 :54163374|FS of Child2 :5
#
# Thread 26175304 Generation 13 |Child1 :06177304|FS of Child1: 6|Child2 :23177304|FS of Child2 :6
#
#
# Thread 25164073 Generation 16 |Child1 :34164073|FS of Child1: 6|Child2 :54164023|FS of Child2 :5
#
# Thread 25703641 Generation 13 |Child1 :25753741|FS of Child1: 6|Child2 :25733241|FS of Child2 :6
#
# Thread 37046152 Generation 2 |Child1 :71046065|FS of Child1: 3|Child2 :35074552|FS of Child2 :4
# Thread 14630752 Generation 21 |Child1 :14221752|FS of Child1: 5|Child2 :14133252|FS of Child2 :5
#
# Thread 37025164 Generation 3 |Child1 :17032567|FS of Child1: 3|Child2 :37031624|FS of Child2 :4
#
# Thread 40357162 Generation 2 |Child1 :60355160|FS of Child1: 5|Child2 :60356166|FS of Child2 :5
#
#
# Thread 13572064 Generation 22 |Child1 :14572064|FS of Child1: 7|Child2 :10552064|FS of Child2 :6
#
#
#
# Thread 06471352 Generation 26 |Child1 :06434357|FS of Child1: 5|Child2 :06431377|FS of Child2 :5
#
# Thread 25317460 Generation 10 |Child1 :64527467|FS of Child1: 3|Child2 :61747462|FS of Child2 :3
# Thread 26174035 Generation 12 |Child1 :56734037|FS of Child1: 4|Child2 :56474017|FS of Child2 :4
#
# Thread 36420571 Generation 4 |Child1 :51424571|FS of Child1: 5|Child2 :51424671|FS of Child2 :4
# Thread 36415027 Generation 3 |Child1 :53706027|FS of Child1: 3|Child2 :03315027|FS of Child2 :5
# Thread 15720364 Generation 21 |Child1 :17640761|FS of Child1: 3|Child2 :15040262|FS of Child2 :4
# Thread 17502463 Generation 18 |Child1 :77501561|FS of Child1: 4|Child2 :07501461|FS of Child2 :5
# Thread 04752613 Generation 28 |Child1 :04753603|FS of Child1: 6|Child2 :04752606|FS of Child2 :6
# Thread 30471625 Generation 10 |Child1 :34401327|FS of Child1: 4|Child2 :70412525|FS of Child2 :4
# Thread 31625740 Generation 12 |Child1 :31653760|FS of Child1: 5|Child2 :32603720|FS of Child2 :4
# Thread 41506372 Generation 0 |Child1 :42006272|FS of Child1: 5|Child2 :71246306|FS of Child2 :3
# Thread 31475026 Generation 9 |Child1 :30455026|FS of Child1: 6|Child2 :32475626|FS of Child2 :6
# Thread 31640752 Generation 11 |Child1 :31625350|FS of Child1: 4|Child2 :06630350|FS of Child2 :3
# Thread 35716024 Generation 6 |Child1 :65737044|FS of Child1: 4|Child2 :73737024|FS of Child2 :4
# Thread 06357142 Generation 23 |Child1 :00377512|FS of Child1: 4|Child2 :00377262|FS of Child2 :4
#
# Thread 31746025 Generation 10 |Child1 :31276020|FS of Child1: 5|Child2 :17736020|FS of Child2 :4
#
#
# Thread 36074152 Generation 5 |Child1 :56054022|FS of Child1: 4|Child2 :02074056|FS of Child2 :4
#
#
# Thread 36271405 Generation 5 |Child1 :76211454|FS of Child1: 4|Child2 :66211421|FS of Child2 :4
#
#
#
#
#
#
# Thread 31750246 Generation 8 |Child1 :30750246|FS of Child1: 7|Child2 :30756247|FS of Child2 :5
#
# Thread 24175360 Generation 20 |Child1 :05175300|FS of Child1: 5|Child2 :04170300|FS of Child2 :5
# Thread 16470352 Generation 18 |Child1 :56420350|FS of Child1: 5|Child2 :26020352|FS of Child2 :5
#
#
# Thread 35041726 Generation 8 |Child1 :25001246|FS of Child1: 4|Child2 :34001206|FS of Child2 :4
# Thread 24603175 Generation 21 |Child1 :26301155|FS of Child1: 4|Child2 :24001125|FS of Child2 :5
#
# Thread 26175304 Generation 14 |Child1 :26677304|FS of Child1: 6|Child2 :25177304|FS of Child2 :6
#
#
# Thread 13572064 Generation 23 |Child1 :13572064|FS of Child1: 8|Child2 :10472064|FS of Child2 :6
#
#
#
#
#
#
#
#
#  ***** 13572064 is the correct sequence which is generated first in generation no :24 *****
